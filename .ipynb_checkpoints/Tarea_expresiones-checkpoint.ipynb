# %%
##Tarea Expresiones Regulares
##Nombre: JimmyYumbo

# %%
import re
import csv
import pandas as pd 
import openpyxl
import requests
from pathlib import Path

# %%
with open('pubmed-oncogenest-set.txt', "r", encoding='utf-8-sig') as f:
      Text = f.read()
Text = re.sub(r'\s{6}',' ', Text)

paises = re.findall(r'\,\s[A-zA-Z]{2,11}\.\s', Text)
#paises = re.findall(r'[A-Z]{2}\s(\d{5}), world', Text)
#paises = re.findall(r'AD{2}', Text)
#paises = re.findall(r'[A-Z]{2}\s\w', Text)
print(paises)
# Out:
# [', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', Greece.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', Basel.\n', ', China.\n', ', China.\n', ', USA.\n', ', USA.\n', ', China.\n', ', China.\n', ', China.\n', ', China.\n', ', China.\n', ', USA.\n', ', China.\n', ', China.\n', ', China.\n', ', USA.\n', ', USA.\n', ', Germany.\n', ', China.\n', ', China.\n', ', China. ', ', Germany. ', ', USA. ', ', Germany.\n', ', Germany.\n', ', Germany.\n', ', Turkey.\n', ', Turkey.\n', ', Turkey.\n', ', Turkey.\n', ', Turkey. ', ', USA. ', ', USA. ', ', Germany.\n', ', Germany.\n', ', Germany.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', USA.\n', ', U
# ...

# %%
Tablapaises = pd.read_csv("Tabla_de_paises.csv") 
print(Tablapaises)
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2            Unnamed: 3
# 0          NaN         NaN        NaN                   NaN
# 1      country    latitude  longitude                  name
# 2           AD   42.546245   1.601554               Andorra
# 3           AE   23.424076  53.847818  United Arab Emirates
# 4           AF    33.93911  67.709953           Afghanistan
# ..         ...         ...        ...                   ...
# 242         YE   15.552727  48.516388                 Yemen
# 243         YT    -12.8275  45.166244               Mayotte
# 244         ZA  -30.559482  22.937506          South Africa
# 245         ZM  -13.133897  27.849332                Zambia
# 246         ZW  -19.015438  29.154857              Zimbabwe
#
# [247 rows x 4 columns]

# %%
zip_coordinates = {}
with open('Tabla_de_paises.csv') as f:
    csv_data = pd.read_csv(f)
    for row in csvr:
        zip_coordinates[row['ZIP']] = [float(row['LAT']), 
                                       float(row['LGT'])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8112/972203938.py in <module>
#       2 with open('Tabla_de_paises.csv') as f:
#       3     csv_data = pd.read_csv(f)
# ----> 4     for row in csvr:
#       5         zip_coordinates[row['ZIP']] = [float(row['LAT']),
#       6                                        float(row['LGT'])]
#
# ~\anaconda3\lib\csv.py in __next__(self)
#     109             # Used only for its side effect.
#     110             self.fieldnames
# --> 111         row = next(self.reader)
#     112         self.line_num = self.reader.line_num
#     113
#
# ValueError: I/O operation on closed file.

# %%
print(Text[:2000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8112/3380257953.py in <module>
# ----> 1 print(Text[:2000])
#
# NameError: name 'Text' is not defined

# %%
zipcodes = re.findall(r'[A-Z]{2}\s(\d{5}), USA', Text)

# %%
len(zipcodes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8112/593862592.py in <module>
# ----> 1 len(zipcodes)
#
# NameError: name 'zipcodes' is not defined

# %%
zipcodes[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8112/80757399.py in <module>
# ----> 1 zipcodes[:10]
#
# NameError: name 'zipcodes' is not defined
