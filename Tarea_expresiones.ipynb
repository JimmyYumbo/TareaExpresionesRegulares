# %%
##Tarea Expresiones Regulares
##Nombre: JimmyYumbo

# %%
import re
import csv
import pandas as pd 
import openpyxl
import requests
from pathlib import Path

# %%
with open('pubmed-oncogenest-set.txt', "r", encoding='utf-8-sig') as f:
      Text = f.read()
Text = re.sub(r'\s{6}',' ', Text)
len(Text)
Text = re.sub(r'\n\s{6}', ' ', Text)
paises = re.findall(r'\,\s[A-zA-Z]{3,11}\.', Text)
#paises = re.findall(r'[A-Z]{2}\s(\d{5}), world', Text)
#paises = re.findall(r'AD{2}', Text)
#paises = re.findall(r'[A-Z]{2}\s\w', Text)
print(paises)
len(paises)
# Out:
# [', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', Greece.', ', USA.', ', USA.', ', USA.', ', Basel.', ', China.', ', China.', ', USA.', ', USA.', ', China.', ', China.', ', China.', ', China.', ', China.', ', USA.', ', China.', ', China.', ', China.', ', USA.', ', USA.', ', Germany.', ', China.', ', China.', ', China.', ', Germany.', ', USA.', ', Germany.', ', Germany.', ', Germany.', ', Turkey.', ', Turkey.', ', Turkey.', ', Turkey.', ', Turkey.', ', USA.', ', USA.', ', Germany.', ', Germany.', ', Germany.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', USA.', ', Finland.', ', Finland.', ', Finland.', ', Finland.', ', Egypt.', ', Egypt.', ', USA.', ', China.', ', China.', ', China.', ', Chi
# ...

# %%
paises[:1000]
Tablapaises = pd.read_csv("coordinates.csv") 
print(Tablapaises)
paises_zipcodes = list(set(paises))
paises_zipcodes.sort()
paises_zipcodes[:1000]
len(paises_zipcodes)
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]
# 312

# %%
mydict= {}
#zip_coordinates = {}
with open('coordinates.csv', mode='r') as inp:
    reader = csv.reader(inp)
    dict_from_csv = {rows[1]:rows[2] for rows in reader}
    print(dict_from_csv)
# Out:
# {'latitude': 'longitude', '42.546245': '1.601554', '23.424076': '53.847818', '33.93911': '67.709953', '17.060816': '-61.796428', '18.220554': '-63.068615', '41.153332': '20.168331', '40.069099': '45.038189', '12.226079': '-69.060087', '-11.202692': '17.873887', '-75.250973': '-0.071389', '-38.416097': '-63.616672', '-14.270972': '-170.132217', '47.516231': '14.550072', '-25.274398': '133.775136', '12.52111': '-69.968338', '40.143105': '47.576927', '43.915886': '17.679076', '13.193887': '-59.543198', '23.684994': '90.356331', '50.503887': '4.469936', '12.238333': '-1.561593', '42.733883': '25.48583', '25.930414': '50.637772', '-3.373056': '29.918886', '9.30769': '2.315834', '32.321384': '-64.75737', '4.535277': '114.727669', '-16.290154': '-63.588653', '-14.235004': '-51.92528', '25.03428': '-77.39628', '27.514162': '90.433601', '-54.423199': '3.413194', '-22.328474': '24.684866', '53.709807': '27.953389', '17.189877': '-88.49765', '56.130366': '-106.346771', '-12.164165': '96.870956'
# ...

# %%
import csv
Tcoordinates = {}
with open('Tcoordinates.txt') as f:
    csvr = csv.DictReader(f)
    for row in csvr:
        Tcoordinates[row['name']] = [(row['latitude']), (row['longitude'])]

# %%
zip_name = []
zip_longitude = []
zip_latitude = []
zip_country = []

# %%
for z in Text:
    if z in Tcoordinates.keys():
        zip_name.append(z)
        zip_latitude.append(Tcoordinates[z][0])
        zip_longitude.append(Tcoordinates[z][1])
        zip_country.append(zip_country(z))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(zip_longitude, zip_latitude, s = zip_country, c= zip_country)
plt.colorbar()
# only continental us without Alaska
plt.xlim(-125,150)
plt.ylim(-50, 150)
# add a few cities for reference (optional)
ard = dict(arrowstyle="->")
plt.annotate('USA', xy = (-95.712891,37.09024), 
               xytext = (-80,25), arrowprops = ard)
plt.annotate('UK', xy = (-3.435973, 55.378051), 
               xytext = (-30, 55), arrowprops= ard)
plt.annotate('Brazil', xy = (-51, 5), 
               xytext = (-51.92528, -14.235004), arrowprops= ard)
plt.annotate('China', xy = (104.195397, 35.86166), 
               xytext = (80, 35), arrowprops= ard)
plt.annotate('Australia', xy = (133.775136, -25.274398), 
               xytext = (100, -25), arrowprops= ard)
plt.annotate('Norway', xy = (8.468946, 60.472024), 
               xytext = (8, 45), arrowprops= ard)
params = plt.gcf()
plSize = params.get_size_inches()
params.set_size_inches( (plSize[0] * 3, plSize[1] * 3) )
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8112/593862592.py in <module>
# ----> 1 len(zipcodes)
#
# NameError: name 'zipcodes' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8112/80757399.py in <module>
# ----> 1 zipcodes[:10]
#
# NameError: name 'zipcodes' is not defined
